# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(64)

def step_function(y):
    if y < 0:
        return 0
    else:
        return 1
    
if __name__ == "__main__":
    data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    w = np.random.rand(3)
    t = np.array([0, 0, 0, 1]) #AND
    #t = np.array([0, 1, 1, 1]) #OR
    #t = np.array([0, 1, 1, 0]) #XOR
    
    alpha = 0.01
    err=[]
    
    for epoch in range(100):
        y_pred=[]
        
        for i in range(4):
            
            #forward network
            out = w[0]*data[i][0] + w[1]*data[i][1]+ w[2]
            y = step_function(out)
            
            #training
            w[0] = w[0] + alpha*((t[i])-y)*data[i][0]
            w[1] = w[1] + alpha*((t[i])-y)*data[i][1]
            w[2] = w[2] + alpha*((t[i])-y)
            
            y_pred.append(y)
            
        #Evaluate
        MSE = 0.5 * np.sum((np.array(y_pred)-t)**2)
        err.append(MSE)
        print('Epoch{}:, Pred:{}, T:{}'.format(epoch, y_pred, t)) 
    
    plt.plot(err)
    plt.xlabel('epoch')
    plt.ylabel('MSE')
    plt.show
# Out:
# Epoch0:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch1:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch2:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch3:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch4:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch5:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch6:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch7:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch8:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch9:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch10:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch11:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch12:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch13:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch14:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch15:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch16:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch17:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch18:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch19:, Pred:[1, 1, 1, 1], T:[0 0 0 1]
# Epoch20:, Pred:[0, 1, 1, 1], T:[0 0 0 1]
# Epoch21:, Pred:[0, 1, 1, 1], T:[0 0 0 1]
# Epoch22:, Pred:[0, 1, 1, 1], T:[0 0 0 1]
# Epoch23:, Pred:[0, 1, 1, 1], T:[0 0 0 1]
# Epoch24:, Pred:[0, 1, 1, 1], T:[0 0 0 1]
# Epoch25:, Pred:[0, 1, 1, 1], T:[0 0 0 1]
# Epoch26:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch27:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch28:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch29:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch30:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch31:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch32:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch33:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch34:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch35:, Pred:[0, 1, 0, 1], T:[0 0 0 1]
# Epoch36:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch37:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch38:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch39:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch40:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch41:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch42:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch43:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch44:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch45:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch46:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch47:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch48:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch49:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch50:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch51:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch52:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch53:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch54:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch55:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch56:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch57:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch58:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch59:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch60:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch61:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch62:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch63:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch64:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch65:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch66:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch67:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch68:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch69:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch70:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch71:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch72:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch73:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch74:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch75:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch76:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch77:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch78:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch79:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch80:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch81:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch82:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch83:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch84:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch85:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch86:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch87:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch88:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch89:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch90:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch91:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch92:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch93:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch94:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch95:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch96:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch97:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch98:, Pred:[0, 0, 0, 1], T:[0 0 0 1]
# Epoch99:, Pred:[0, 0, 0, 1], T:[0 0 0 1]

# %%
np.random.seed(64)

def step_function(y):
    if y < 0:
        return 0
    else:
        return 1
    
if __name__ == "__main__":
    data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    w = np.random.rand(3)
    #t = np.array([0, 0, 0, 1]) #AND
    t = np.array([0, 1, 1, 1]) #OR
    #t = np.array([0, 1, 1, 0]) #XOR
    
    alpha = 0.01
    err=[]
    
    for epoch in range(100):
        y_pred=[]
        
        for i in range(4):
            
            #forward network
            out = w[0]*data[i][0] + w[1]*data[i][1]+ w[2]
            y = step_function(out)
            
            #training
            w[0] = w[0] + alpha*((t[i])-y)*data[i][0]
            w[1] = w[1] + alpha*((t[i])-y)*data[i][1]
            w[2] = w[2] + alpha*((t[i])-y)
            
            y_pred.append(y)
            
        #Evaluate
        MSE = 0.5 * np.sum((np.array(y_pred)-t)**2)
        err.append(MSE)
        print('Epoch{}:, Pred:{}, T:{}'.format(epoch, y_pred, t)) 
    
    plt.plot(err)
    plt.xlabel('epoch')
    plt.ylabel('MSE')
    plt.show
# Out:
# Epoch0:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch1:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch2:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch3:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch4:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch5:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch6:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch7:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch8:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch9:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch10:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch11:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch12:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch13:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch14:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch15:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch16:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch17:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch18:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch19:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch20:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch21:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch22:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch23:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch24:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch25:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch26:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch27:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch28:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch29:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch30:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch31:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch32:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch33:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch34:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch35:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch36:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch37:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch38:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch39:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch40:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch41:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch42:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch43:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch44:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch45:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch46:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch47:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch48:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch49:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch50:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch51:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch52:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch53:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch54:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch55:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch56:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch57:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch58:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch59:, Pred:[1, 1, 1, 1], T:[0 1 1 1]
# Epoch60:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch61:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch62:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch63:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch64:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch65:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch66:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch67:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch68:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch69:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch70:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch71:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch72:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch73:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch74:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch75:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch76:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch77:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch78:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch79:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch80:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch81:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch82:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch83:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch84:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch85:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch86:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch87:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch88:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch89:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch90:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch91:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch92:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch93:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch94:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch95:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch96:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch97:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch98:, Pred:[0, 1, 1, 1], T:[0 1 1 1]
# Epoch99:, Pred:[0, 1, 1, 1], T:[0 1 1 1]

# %%
np.random.seed(64)

def step_function(y):
    if y < 0:
        return 0
    else:
        return 1
    
if __name__ == "__main__":
    data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    w = np.random.rand(3)
    #t = np.array([0, 0, 0, 1]) #AND
    #t = np.array([0, 1, 1, 1]) #OR
    t = np.array([0, 1, 1, 0]) #XOR
    
    alpha = 0.01
    err=[]
    
    for epoch in range(100):
        y_pred=[]
        
        for i in range(4):
            
            #forward network
            out = w[0]*data[i][0] + w[1]*data[i][1]+ w[2]
            y = step_function(out)
            
            #training
            w[0] = w[0] + alpha*((t[i])-y)*data[i][0]
            w[1] = w[1] + alpha*((t[i])-y)*data[i][1]
            w[2] = w[2] + alpha*((t[i])-y)
            
            y_pred.append(y)
            
        #Evaluate
        MSE = 0.5 * np.sum((np.array(y_pred)-t)**2)
        err.append(MSE)
        print('Epoch{}:, Pred:{}, T:{}'.format(epoch, y_pred, t)) 
    
    plt.plot(err)
    plt.xlabel('epoch')
    plt.ylabel('MSE')
    plt.show
# Out:
# Epoch0:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch1:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch2:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch3:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch4:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch5:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch6:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch7:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch8:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch9:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch10:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch11:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch12:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch13:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch14:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch15:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch16:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch17:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch18:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch19:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch20:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch21:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch22:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch23:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch24:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch25:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch26:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch27:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch28:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch29:, Pred:[1, 1, 1, 1], T:[0 1 1 0]
# Epoch30:, Pred:[0, 1, 1, 1], T:[0 1 1 0]
# Epoch31:, Pred:[0, 1, 1, 1], T:[0 1 1 0]
# Epoch32:, Pred:[0, 1, 1, 1], T:[0 1 1 0]
# Epoch33:, Pred:[0, 1, 1, 1], T:[0 1 1 0]
# Epoch34:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch35:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch36:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch37:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch38:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch39:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch40:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch41:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch42:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch43:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch44:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch45:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch46:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch47:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch48:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch49:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch50:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch51:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch52:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch53:, Pred:[0, 0, 1, 1], T:[0 1 1 0]
# Epoch54:, Pred:[0, 0, 0, 1], T:[0 1 1 0]
# Epoch55:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch56:, Pred:[0, 0, 1, 1], T:[0 1 1 0]
# Epoch57:, Pred:[0, 0, 0, 1], T:[0 1 1 0]
# Epoch58:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch59:, Pred:[0, 0, 1, 1], T:[0 1 1 0]
# Epoch60:, Pred:[0, 0, 0, 1], T:[0 1 1 0]
# Epoch61:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch62:, Pred:[0, 0, 1, 1], T:[0 1 1 0]
# Epoch63:, Pred:[0, 0, 0, 1], T:[0 1 1 0]
# Epoch64:, Pred:[0, 1, 0, 1], T:[0 1 1 0]
# Epoch65:, Pred:[0, 0, 1, 1], T:[0 1 1 0]
# Epoch66:, Pred:[0, 0, 0, 1], T:[0 1 1 0]
# Epoch67:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch68:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch69:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch70:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch71:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch72:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch73:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch74:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch75:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch76:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch77:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch78:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch79:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch80:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch81:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch82:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch83:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch84:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch85:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch86:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch87:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch88:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch89:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch90:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch91:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch92:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch93:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch94:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch95:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch96:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch97:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch98:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
# Epoch99:, Pred:[1, 0, 0, 1], T:[0 1 1 0]
